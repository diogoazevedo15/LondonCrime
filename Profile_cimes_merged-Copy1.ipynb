# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import os
from pandas_profiling import ProfileReport

# %% [markdown]
# #### Load csv

# %%
crimes = pd.read_csv('D:/Universidade-Fcul/2_semestre/TPD/projeto/crimes_merged.csv')
crimes.head()
# Out:
#    lsoa_code         borough               major_category minor_category  \
# 0  E01000002  City of London  Violence Against the Person     Harassment
# 1  E01000005  City of London  Violence Against the Person     Harassment
# 2  E01000001  City of London  Violence Against the Person     Harassment
# 3  E01032739  City of London  Violence Against the Person     Harassment
# 4  E01000001  City of London  Violence Against the Person     Harassment
#
#    value  year  month
# 0      0  2011      9
# 1      0  2014      7
# 2      0  2008      3
# 3      0  2016      3
# 4      0  2011     10

# %% [markdown]
# #### Drop and cast columns

# %%
crimes = crimes.drop(columns = ['lsoa_code'])
crimes['year'] = crimes['year'].astype(str)
crimes['month'] = crimes['month'].astype(str)
crimes.head()
# Out:
#           borough               major_category minor_category  value  year  \
# 0  City of London  Violence Against the Person     Harassment      0  2011
# 1  City of London  Violence Against the Person     Harassment      0  2014
# 2  City of London  Violence Against the Person     Harassment      0  2008
# 3  City of London  Violence Against the Person     Harassment      0  2016
# 4  City of London  Violence Against the Person     Harassment      0  2011
#
#   month
# 0     9
# 1     7
# 2     3
# 3     3
# 4    10

# %%
# profile = ProfileReport(crimes, title='Crimes Profiling Report', explorative=1, minimal =1)

# %%
# profile

# %% [markdown]
# #### Interesting info

# %% [markdown]
# * **value**: Esta coluna apresenta 2895341 valores = 0. Ou seja temos 2895341 linhas, que correspondem a 0 ocorrencias de um certo crime, num dado ano, mês e localização. Fará então sentido eliminar estas linhas, e considerar que a omissão de um certo crime num dado ano, mês e localização, como a sua não ocorrencia.

# %% [markdown]
# ![alt text](images/value_profile.PNG "Value Profile")

# %%
crimes = crimes.drop(crimes.index[crimes['value'] == 0])
print(crimes.shape[0])
crimes.head()
# Out:
# 990907
#            borough               major_category minor_category  value  year  \
# 16  City of London  Violence Against the Person     Harassment      1  2013
# 40  City of London  Violence Against the Person     Harassment      1  2015
# 44  City of London  Violence Against the Person     Harassment      1  2013
# 55  City of London  Violence Against the Person     Harassment      1  2011
# 90  City of London  Violence Against the Person     Harassment      1  2016
#
#    month
# 16     7
# 40     5
# 44     8
# 55    10
# 90     4

# %% [markdown]
# * **year**: Na coluna 'year', conseguimos ver que a grande maioria dos dados deste dataframe correspondem a crimes entre 2008-2016. Os dados referentes a 2017 e 2018 são têm um volume menor, pois são dados provenientes de um outro dataframe, com um numero inferior de entradas.

# %% [markdown]
# ![alt text](images/year.PNG "Value Title")

# %% [markdown]
# ### Crete tables

# %% [markdown]
# #### Crimes tables: Major | Minor | Crime

# %%
crimes_df = crimes[['major_category', 'minor_category']].drop_duplicates()
crimes_df
# Out:
#                       major_category                          minor_category
# 16       Violence Against the Person                              Harassment
# 101               Theft and Handling                             Other Theft
# 232      Violence Against the Person                            Wounding/GBH
# 289      Violence Against the Person                          Common Assault
# 356      Violence Against the Person                          Other violence
# 436                            Drugs                        Drug Trafficking
# 473      Violence Against the Person                        Offensive Weapon
# 500        Other Notifiable Offences                        Other Notifiable
# 555               Theft and Handling                        Theft From Shops
# 636                          Robbery                       Business Property
# 667                          Robbery                       Personal Property
# 708               Theft and Handling                      Other Theft Person
# 797      Violence Against the Person                     Assault with Injury
# 844                            Drugs                     Possession Of Drugs
# 914               Theft and Handling                   Handling Stolen Goods
# 1036              Theft and Handling                Theft From Motor Vehicle
# 1108                        Burglary             Burglary in Other Buildings
# 1187              Theft and Handling             Theft/Taking of Pedal Cycle
# 1230              Theft and Handling           Theft/Taking Of Motor Vehicle
# 1333                 Criminal Damage        Criminal Damage To Motor Vehicle
# 1388                 Criminal Damage       Criminal Damage To Other Building
# 1479                 Sexual Offences                                    Rape
# 1813     Violence Against the Person                                  Murder
# 5370                           Drugs                             Other Drugs
# 9674                 Sexual Offences                            Other Sexual
# 16391      Other Notifiable Offences                          Going Equipped
# 38311               Fraud or Forgery                      Counted per Victim
# 50998                Criminal Damage                   Other Criminal Damage
# 54202               Fraud or Forgery                   Other Fraud & Forgery
# 54560                       Burglary                  Burglary in a Dwelling
# 63995                Criminal Damage             Criminal Damage To Dwelling
# 79659             Theft and Handling  Motor Vehicle Interference & Tampering
# 3861000                     Burglary       Burglary - Business and Community
# 3861024                     Burglary                  Burglary - Residential
# 3861048              Criminal Damage                                   Arson
# 3861072              Criminal Damage                  Criminal Damage To M/V
# 3861096              Criminal Damage           Criminal Damage To Other Bldg
# 3861120              Criminal Damage           Criminal Damage To a Dwelling
# 3861208                        Drugs                     Other Drug Offences
# 3861432           Theft and Handling            M/V Interference & Tampering
# 3861480           Theft and Handling                          Theft From M/V
# 3861528           Theft and Handling                            Theft Person
# 3861552           Theft and Handling                     Theft/Taking of M/V
# 3861576           Theft and Handling            Theft/Taking of Pedal Cycles
# 3861720  Violence Against the Person                          Other Violence

# %% [markdown]
# #### Major Table

# %%
major_category_table = pd.DataFrame(crimes_df['major_category'].unique(), columns=['major_category'])
major_category_table['major_category_id'] = major_category_table.index 
major_category_table.head()
# Out:
#                 major_category  major_category_id
# 0  Violence Against the Person                  0
# 1           Theft and Handling                  1
# 2                        Drugs                  2
# 3    Other Notifiable Offences                  3
# 4                      Robbery                  4

# %% [markdown]
# #### Minor Table

# %%
minor_category_table = pd.DataFrame(crimes_df['minor_category'].unique(), columns=['minor_category'])
minor_category_table['minor_category_id'] = minor_category_table.index 
minor_category_table.head()
# Out:
#    minor_category  minor_category_id
# 0      Harassment                  0
# 1     Other Theft                  1
# 2    Wounding/GBH                  2
# 3  Common Assault                  3
# 4  Other violence                  4

# %% [markdown]
# #### Crimes Table

# %%
for r in crimes_df.iterrows():
    crimes_df.at[r[0],'major_category'] = major_category_table.loc[major_category_table['major_category'] == r[1][0]]['major_category_id'].index[0]
    crimes_df.at[r[0],'minor_category'] = minor_category_table.loc[minor_category_table['minor_category'] == r[1][1]]['minor_category_id'].index[0]

crimes_df = crimes_df.reset_index(drop=True)
crimes_df['crime_id'] = crimes_df.index

# %%
crimes_df.head()
# Out:
#   major_category minor_category  crime_id
# 0              0              0         0
# 1              1              1         1
# 2              0              2         2
# 3              0              3         3
# 4              0              4         4

# %% [markdown]
# #### Date Dataframe

# %%
date_df = crimes[['year', 'month']].drop_duplicates()

date_df.head()
date_df = date_df.reset_index(drop=True)
date_df['date_id'] = date_df.index

date_df.head()
# Out:
#    year month  date_id
# 0  2013     7        0
# 1  2015     5        1
# 2  2013     8        2
# 3  2011    10        3
# 4  2016     4        4

# %%
crimes['crime_id'] = 'nan'
crimes['date_id'] = 'nan'
crimes['borough_id'] = 'nan'
crimes
# Out:
#                 borough               major_category minor_category  value  \
# 16       City of London  Violence Against the Person     Harassment      1
# 40       City of London  Violence Against the Person     Harassment      1
# 44       City of London  Violence Against the Person     Harassment      1
# 55       City of London  Violence Against the Person     Harassment      1
# 90       City of London  Violence Against the Person     Harassment      1
# ...                 ...                          ...            ...    ...
# 3886243     Westminster  Violence Against the Person   Wounding/GBH     87
# 3886244     Westminster  Violence Against the Person   Wounding/GBH    117
# 3886245     Westminster  Violence Against the Person   Wounding/GBH    101
# 3886246     Westminster  Violence Against the Person   Wounding/GBH    130
# 3886247     Westminster  Violence Against the Person   Wounding/GBH    107
#
#          year month crime_id date_id borough_id
# 16       2013     7      nan     nan        nan
# 40       2015     5      nan     nan        nan
# 44       2013     8      nan     nan        nan
# 55       2011    10      nan     nan        nan
# 90       2016     4      nan     nan        nan
# ...       ...   ...      ...     ...        ...
# 3886243  2018     4      nan     nan        nan
# 3886244  2018     5      nan     nan        nan
# 3886245  2018     6      nan     nan        nan
# 3886246  2018     7      nan     nan        nan
# 3886247  2018     8      nan     nan        nan
#
# [990907 rows x 9 columns]

# %%
crimes = crimes[crimes['borough'] != 'City of London']

# %%
crimes
# Out:
#              borough               major_category minor_category  value  year  \
# 1479          Ealing              Sexual Offences           Rape      1  2008
# 1813          Ealing  Violence Against the Person         Murder      1  2011
# 1819          Ealing  Violence Against the Person         Murder      1  2012
# 1886          Ealing  Violence Against the Person         Murder      1  2008
# 1904          Ealing  Violence Against the Person         Murder      1  2010
# ...              ...                          ...            ...    ...   ...
# 3886243  Westminster  Violence Against the Person   Wounding/GBH     87  2018
# 3886244  Westminster  Violence Against the Person   Wounding/GBH    117  2018
# 3886245  Westminster  Violence Against the Person   Wounding/GBH    101  2018
# 3886246  Westminster  Violence Against the Person   Wounding/GBH    130  2018
# 3886247  Westminster  Violence Against the Person   Wounding/GBH    107  2018
#
#         month crime_id date_id borough_id
# 1479        2      nan     nan        nan
# 1813        5      nan     nan        nan
# 1819       11      nan     nan        nan
# 1886        9      nan     nan        nan
# 1904        5      nan     nan        nan
# ...       ...      ...     ...        ...
# 3886243     4      nan     nan        nan
# 3886244     5      nan     nan        nan
# 3886245     6      nan     nan        nan
# 3886246     7      nan     nan        nan
# 3886247     8      nan     nan        nan
#
# [990342 rows x 9 columns]

# %%
#load demographics

demographics = pd.read_csv('D:/Universidade-Fcul/2_semestre/TPD/projeto/demographics.csv')
demographics.head()
# Out:
#               Area name Inner/ Outer London  GLA Population Estimate 2016  \
# 0  Barking and Dagenham        Outer London                      205773.0
# 1                Barnet        Outer London                      385108.0
# 2                Bexley        Outer London                      243303.0
# 3                 Brent        Outer London                      328568.0
# 4               Bromley        Outer London                      326560.0
#
#    GLA Household Estimate 2016  Inland Area (Hectares)  \
# 0                      76841.0                  3610.8
# 1                     149147.0                  8674.8
# 2                      97233.0                  6058.1
# 3                     119166.0                  4323.3
# 4                     139654.0                 15013.5
#
#    Population density (per hectare) 2016  Average Age, 2016  \
# 0                                   57.3               32.9
# 1                                   44.5               37.2
# 2                                   39.9               38.9
# 3                                   76.1               35.5
# 4                                   21.7               40.1
#
#    Proportion of population aged 0-15, 2016  \
# 0                                      21.0
# 1                                      21.0
# 2                                      20.8
# 3                                      20.1
# 4                                      15.8
#
#    Proportion of population of working-age, 2016  \
# 0                                           86.1
# 1                                           83.3
# 2                                           89.0
# 3                                           82.5
# 4                                           88.4
#
#    Proportion of population aged 65 and over, 2016  ...  \
# 0                                             13.9  ...
# 1                                             16.7  ...
# 2                                             11.0  ...
# 3                                             17.5  ...
# 4                                             11.6  ...
#
#    Anxiety score 2011-14 (out of 10)  \
# 0                               3.05
# 1                               2.75
# 2                               3.29
# 3                               2.92
# 4                               3.26
#
#    Childhood Obesity Prevalance (%) 2014/15  \
# 0                                      25.3
# 1                                      18.4
# 2                                      21.4
# 3                                      23.9
# 4                                      16.5
#
#    Mortality rate from causes considered preventable 2012/14  \
# 0                                              227.6
# 1                                              133.8
# 2                                              164.3
# 3                                              169.4
# 4                                              148.5
#
#    Political control in council  \
# 0                           Lab
# 1                          Cons
# 2                          Cons
# 3                           Lab
# 4                          Cons
#
#   Proportion of seats won by Conservatives in 2014 election  \
# 0                                                0.0
# 1                                               50.8
# 2                                               71.4
# 3                                                9.5
# 4                                               85.0
#
#    Proportion of seats won by Labour in 2014 election  \
# 0                                              100.0
# 1                                               47.6
# 2                                               23.8
# 3                                               88.9
# 4                                               11.7
#
#   Proportion of seats won by Lib Dems in 2014 election  \
# 0                                                0.0
# 1                                                1.6
# 2                                                0.0
# 3                                                1.6
# 4                                                0.0
#
#    Turnout at 2014 local elections borrough_id  borough_id
# 0                             36.5           0           0
# 1                             40.5           1           1
# 2                             39.6           2           2
# 3                             36.3           3           3
# 4                             40.8           4           4
#
# [5 rows x 79 columns]

# %%
demographics_aux = demographics[['Area name','borough_id']]
demographics_aux = demographics_aux.rename(columns = {'Area name': 'borough'})

# %%
crimes
# Out:
#              borough               major_category minor_category  value  year  \
# 1479          Ealing              Sexual Offences           Rape      1  2008
# 1813          Ealing  Violence Against the Person         Murder      1  2011
# 1819          Ealing  Violence Against the Person         Murder      1  2012
# 1886          Ealing  Violence Against the Person         Murder      1  2008
# 1904          Ealing  Violence Against the Person         Murder      1  2010
# ...              ...                          ...            ...    ...   ...
# 3886243  Westminster  Violence Against the Person   Wounding/GBH     87  2018
# 3886244  Westminster  Violence Against the Person   Wounding/GBH    117  2018
# 3886245  Westminster  Violence Against the Person   Wounding/GBH    101  2018
# 3886246  Westminster  Violence Against the Person   Wounding/GBH    130  2018
# 3886247  Westminster  Violence Against the Person   Wounding/GBH    107  2018
#
#         month crime_id date_id borough_id
# 1479        2       21      51          7
# 1813        5      nan     nan        nan
# 1819       11      nan     nan        nan
# 1886        9      nan     nan        nan
# 1904        5      nan     nan        nan
# ...       ...      ...     ...        ...
# 3886243     4      nan     nan        nan
# 3886244     5      nan     nan        nan
# 3886245     6      nan     nan        nan
# 3886246     7      nan     nan        nan
# 3886247     8      nan     nan        nan
#
# [990342 rows x 9 columns]

# %%
major_category_table.loc[major_category_table['major_category'] == r[1][1]]['major_category_id'].index[0]
minor_category_table.loc[minor_category_table['minor_category'] == r[1][2]]['minore_category_id'].index[0]
# Out:
# 21

# %%
crimes_df.loc[(crimes_df['major_category'] == major_category_table.loc[major_category_table['major_category'] == 'Sexual Offences']['major_category_id'].index[0])
                  & (crimes_df['minor_category'] == minor_category_table.loc[minor_category_table['minor_category'] == 'Rape']['minor_category_id'].index[0])].crime_id.index[0]
# Out:
# 21

# %%
crimes_df.head()
crimes_df = crimes_df.rename(columns={"major_category": "major_category_id", "minor_category": "minor_category_id"})
crimes_df.head()
# Out:
#   major_category_id minor_category_id  crime_id
# 0                 0                 0         0
# 1                 1                 1         1
# 2                 0                 2         2
# 3                 0                 3         3
# 4                 0                 4         4

# %%
new_df = pd.merge(A_df, B_df,  how='left', left_on=['A_c1','c2'], right_on = ['B_c1','c2'])
demographics_aux

# %%
aux = crimes.merge(major_category_table, on = "major_category")
aux = aux.merge(minor_category_table, on = "minor_category")
aux = aux.merge(crimes_df, on = ["major_category_id","minor_category_id"])
aux = aux.merge(date_df, on = ["year","month"])
aux = aux.merge(demographics_aux, on = ["borough"])
aux
# Out:
#             borough               major_category  \
# 0            Ealing  Violence Against the Person
# 1            Ealing  Violence Against the Person
# 2            Ealing  Violence Against the Person
# 3            Ealing  Violence Against the Person
# 4            Ealing  Violence Against the Person
# ...             ...                          ...
# 989887  Westminster              Criminal Damage
# 989888  Westminster              Criminal Damage
# 989889  Westminster              Sexual Offences
# 989890  Westminster              Sexual Offences
# 989891  Westminster             Fraud or Forgery
#
#                        minor_category  value  year month major_category_id  \
# 0                          Harassment      4  2013     7                 0
# 1                          Harassment      2  2013     7                 0
# 2                          Harassment      1  2013     7                 0
# 3                          Harassment      2  2013     7                 0
# 4                          Harassment      1  2013     7                 0
# ...                               ...    ...   ...   ...               ...
# 989887  Criminal Damage To Other Bldg     34  2018     8                 6
# 989888  Criminal Damage To a Dwelling     22  2018     8                 6
# 989889                           Rape     53  2018     8                 7
# 989890                   Other Sexual     73  2018     8                 7
# 989891          Other Fraud & Forgery      6  2018     8                 8
#
#        minor_category_id  crime_id  date_id  borough_id
# 0                      0         0        0           7
# 1                      0         0        0           7
# 2                      0         0        0           7
# 3                      0         0        0           7
# 4                      0         0        0           7
# ...                  ...       ...      ...         ...
# 989887                36        36      127          31
# 989888                37        37      127          31
# 989889                21        21      127          31
# 989890                24        24      127          31
# 989891                28        28      127          31
#
# [989892 rows x 11 columns]

# %%
fact_table_1 = aux.copy()
fact_table_1 = fact_table_1[['crime_id','date_id','borough_id','value']]
fact_table_1['ocurred_id'] = fact_table_1.index
fact_table_1.to_csv('C:/csvs/fact_table_small.csv', index=False)

# %%
fact_table_2 = aux.copy()
fact_table_2 = fact_table_2[['major_category','minor_category','value','year','month','borough_id']]
fact_table_2['ocurred_id'] = fact_table_2.index
fact_table_2
fact_table_2.to_csv('C:/csvs/fact_table_big.csv', index=False)

# %%
fact_table_1
# Out:
#         crime_id  date_id  borough_id  value  ocurred_id
# 0              0        0           7      4           0
# 1              0        0           7      2           1
# 2              0        0           7      1           2
# 3              0        0           7      2           3
# 4              0        0           7      1           4
# ...          ...      ...         ...    ...         ...
# 989887        36      127          31     34      989887
# 989888        37      127          31     22      989888
# 989889        21      127          31     53      989889
# 989890        24      127          31     73      989890
# 989891        28      127          31      6      989891
#
# [989892 rows x 5 columns]

# %%
for r in crimes.iterrows():
    #Linha feia
    crimes.at[r[0],'crime_id'] = crimes_df.loc[(crimes_df['major_category'] == major_category_table.loc[major_category_table['major_category'] == r[1][1]]['major_category_id'].index[0])
                                  & (crimes_df['minor_category'] == minor_category_table.loc[minor_category_table['minor_category'] == r[1][2]]['minor_category_id'].index[0])].crime_id.index[0]
    
    crimes.at[r[0],'date_id'] = date_df.loc[(date_df['year'] == r[1][4]) & (date_df['month'] == r[1][5])].index[0]
    crimes.at[r[0],'borough_id'] = demographics.loc[(demographics['Area name'] == r[1][0])]['borough_id'].values[0]
#     break

# %%
crimes_df.loc[crimes_df['crime_id'] != 'nan']
# Out:
#    major_category minor_category  crime_id
# 0               0              0         0
# 1               1              1         1
# 2               0              2         2
# 3               0              3         3
# 4               0              4         4
# 5               2              5         5
# 6               0              6         6
# 7               3              7         7
# 8               1              8         8
# 9               4              9         9
# 10              4             10        10
# 11              1             11        11
# 12              0             12        12
# 13              2             13        13
# 14              1             14        14
# 15              1             15        15
# 16              5             16        16
# 17              1             17        17
# 18              1             18        18
# 19              6             19        19
# 20              6             20        20
# 21              7             21        21
# 22              0             22        22
# 23              2             23        23
# 24              7             24        24
# 25              3             25        25
# 26              8             26        26
# 27              6             27        27
# 28              8             28        28
# 29              5             29        29
# 30              6             30        30
# 31              1             31        31
# 32              5             32        32
# 33              5             33        33
# 34              6             34        34
# 35              6             35        35
# 36              6             36        36
# 37              6             37        37
# 38              2             38        38
# 39              1             39        39
# 40              1             40        40
# 41              1             41        41
# 42              1             42        42
# 43              1             43        43
# 44              0             44        44

# %%
ocurred = crimes[['crime_id','date_id','borough_id','value']]
ocurred = ocurred.reset_index(drop = True)
ocurred['ocurred_id'] = ocurred.index
ocurred.head()

# %% [markdown]
# #### Export tables to csv

# %%
major_category_table.head()
# Out:
#                 major_category  major_category_id
# 0  Violence Against the Person                  0
# 1           Theft and Handling                  1
# 2                        Drugs                  2
# 3    Other Notifiable Offences                  3
# 4                      Robbery                  4

# %%
minor_category_table.head()
# Out:
#    minor_category  minor_category_id
# 0      Harassment                  0
# 1     Other Theft                  1
# 2    Wounding/GBH                  2
# 3  Common Assault                  3
# 4  Other violence                  4

# %%
crimes_df.head()
# Out:
#   major_category minor_category  crime_id
# 0              0              0         0
# 1              1              1         1
# 2              0              2         2
# 3              0              3         3
# 4              0              4         4

# %%
ocurred.head()
# Out:
#   crime_id date_id borough_id  value  ocurred_id
# 0       21      51          7      1           0
# 1       22      52          7      1           1
# 2       22      22          7      1           2
# 3       22      53          7      1           3
# 4       22      54          7      1           4

# %%
# compression_opts = dict(method='zip', archive_name='crimes_merged.csv')

# major_category_table.to_csv('major.zip', compression=compression_opts, index=False)
# minor_category_table.to_csv('minor.zip', compression=compression_opts, index=False)
# crimes_df.to_csv('crimes.zip', compression=compression_opts, index=False)
# ocurred.to_csv('ocurred.zip', compression=compression_opts, index=False)

# %%
demographics.to_csv('demographics.zip', compression=compression_opts, index=False)

# %%
dates = crimes[['year','month']].reset_index(drop = 1)

# %%
dates = dates.drop_duplicates().reset_index(drop = 1)

# %%
dates['id'] = dates.index

# %%
dates
# Out:
#      year month   id
# 0    2013     7    0
# 1    2015     5    1
# 2    2013     8    2
# 3    2011    10    3
# 4    2016     4    4
# ..    ...   ...  ...
# 123  2018     4  123
# 124  2018     5  124
# 125  2018     6  125
# 126  2018     7  126
# 127  2018     8  127
#
# [128 rows x 3 columns]

# %%
compression_opts = dict(method='zip', archive_name='date.csv')
date_df.to_csv('date.zip', compression=compression_opts, index=False)
